# %% [markdown]
# # Assignment 1
# ### Thomas Talha Løberg

# %%
from sample_data import available_scenarios, generate_fitness_data
scenarios = available_scenarios()
profile, observation = generate_fitness_data()
print(observation)

class participants:
    def __init__(self, participant_id):
        self.participant_id = participant_id
        

class HeartRate:
    def __init__(self, observations):
        self.list_of_heart_rate = []
        for obs in observations:
            self.list_of_heart_rate.append(obs['heart_rate'])

    def avr_heart_rate(self):
        return sum(self.list_of_heart_rate) / len(self.list_of_heart_rate)

hr = HeartRate(observation)

# %%
print(participant.participant_id)
hr = HeartRate(observation)
print(hearthrate.avr_heart_rate())
# Out:
# P001
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 print(participant.participant_id)
#       2 hr = HeartRate(observation)
# ----> 3 print(hearthrate.avr_heart_rate())
#
# NameError: name 'hearthrate' is not defined
